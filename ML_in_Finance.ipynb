# %%
# Import libraries
import yfinance as yf
import pandas as pd
import numpy as np
from datetime import datetime
import statsmodels.api as sm
import matplotlib.pylab as plt
import warnings
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
#!pip install hdbscan
import hdbscan
import matplotlib.cm as cm
from matplotlib import colors
from sklearn.metrics import adjusted_rand_score
from sklearn import preprocessing
import seaborn as sns
import math
import random
random.seed(108448)
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 9.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (0.29.36)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.22.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->hdbscan) (3.1.0)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039210 sha256=827011f5f8173a270fe4baef8a77981fd6e14914c0fd763572da82ce288a5b69
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
# Successfully built hdbscan
# Installing collected packages: hdbscan
# Successfully installed hdbscan-0.8.33

# %% [markdown]
# # Importing data

# %% [markdown]
# ## Daily discrete returns of S&P500 companies

# %%
# Import companies' list
companies = pd.read_csv('https://raw.githubusercontent.com/petrenaa/ML-in-Finance/main/companies_S&P500.csv', sep = ",")
companies.head()
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                 Pharmaceuticals
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989

# %%
#Import daily stock prices from Yahoo Finance
prices = pd.read_csv('https://raw.githubusercontent.com/petrenaa/ML-in-Finance/main/prices_S&P500.csv', sep = ",", index_col = 'Date')
prices.head()
# Out:
#                              A        AAL         AAP       AAPL       ABBV  \
# Date
# 2018-01-02 00:00:00  64.865387  51.647564   98.501442  40.831593  76.580688
# 2018-01-03 00:00:00  66.515816  51.014030   99.392799  40.824478  77.779076
# 2018-01-04 00:00:00  66.016830  51.335663  103.060249  41.014099  77.335503
# 2018-01-05 00:00:00  67.072334  51.316177  104.155830  41.481060  78.681763
# 2018-01-08 00:00:00  67.216270  50.809349  103.422356  41.326996  77.421112
#
#                            ABC        ABT       ACGL         ACN        ADBE  \
# Date
# 2018-01-02 00:00:00  86.158249  53.636837  29.433332  141.986420  177.699997
# 2018-01-03 00:00:00  86.478920  53.755444  29.459999  142.641693  181.039993
# 2018-01-04 00:00:00  86.286530  53.664204  29.570000  144.330704  183.220001
# 2018-01-05 00:00:00  87.330978  53.819305  29.453333  145.521301  185.339996
# 2018-01-08 00:00:00  88.778549  53.664204  29.456667  146.684219  185.039993
#
#                      ...        WYNN        XEL        XOM       XRAY  \
# Date                 ...
# 2018-01-02 00:00:00  ...  154.383667  40.838547  64.321693  63.636124
# 2018-01-03 00:00:00  ...  152.711105  40.565212  65.584984  63.418129
# 2018-01-04 00:00:00  ...  153.538010  40.249153  65.675758  63.408657
# 2018-01-05 00:00:00  ...  154.562225  39.967278  65.622803  64.299591
# 2018-01-08 00:00:00  ...  152.504379  40.266243  65.917824  64.735573
#
#                            XYL        YUM         ZBH        ZBRA       ZION  \
# Date
# 2018-01-02 00:00:00  63.698143  73.990013  115.467537  103.709999  43.121277
# 2018-01-03 00:00:00  64.474861  73.926552  116.267982  105.769997  43.070251
# 2018-01-04 00:00:00  64.905319  74.679131  116.100449  107.860001  43.248856
# 2018-01-05 00:00:00  64.783669  75.114372  117.254562  109.540001  43.265865
# 2018-01-08 00:00:00  65.017609  75.241333  117.477951  110.629997  43.053230
#
#                            ZTS
# Date
# 2018-01-02 00:00:00  69.280342
# 2018-01-03 00:00:00  69.598877
# 2018-01-04 00:00:00  70.013947
# 2018-01-05 00:00:00  70.815178
# 2018-01-08 00:00:00  71.664642
#
# [5 rows x 503 columns]

# %%
#Turn company names to indices in a companies' list
companies.index = companies['Symbol']

# %%
#Calculating discrete returns
returns = prices.pct_change()

# %%
#Deleting rows and columns with missing data
del_returns = list(prices.columns[prices.isnull().sum() > 1])
returns.drop(del_returns, axis = 1, inplace = True)
returns.dropna(inplace = True)

# %% [markdown]
# ## Fama-French factors

# %%
ff3 = pd.read_csv('https://raw.githubusercontent.com/petrenaa/ML-in-Finance/main/ff3.CSV', sep = ",", dtype = {'Date': str, 'Mkt-RF': float, 'SMB': float, 'HML': float, 'RF': float})

# %%
ff3.columns = ['Date', 'Mkt-RF', 'SMB', 'HML', 'RF-%']
ff3['Date'] = pd.to_datetime(ff3['Date'], format = "%Y-%m-%d %H:%M:%S") #column Date to a datetime format
ff3.index = ff3['Date'] #Date to indices
ff3 = ff3.loc[:, ff3.columns != 'Date'] #Drop Date
ff3 = ff3 / 100 #from % to numbers
ff3.head()
# Out:
#             Mkt-RF     SMB     HML     RF-%
# Date
# 2018-01-02  0.0085  0.0035 -0.0021  0.00006
# 2018-01-03  0.0059 -0.0039 -0.0019  0.00006
# 2018-01-04  0.0042 -0.0026  0.0025  0.00006
# 2018-01-05  0.0066 -0.0035 -0.0025  0.00006
# 2018-01-08  0.0019 -0.0015  0.0004  0.00006

# %%
returns.index = pd.to_datetime(returns.index, format = "%Y-%m-%d %H:%M:%S")

# %% [markdown]
# ##Merging returns and Fama-French factors

# %%
analysis = returns.merge(ff3, on = 'Date')
analysis.head()
# Out:
#                    A       AAL       AAP      AAPL      ABBV       ABC  \
# Date
# 2018-01-03  0.025444 -0.012266  0.009049 -0.000174  0.015649  0.003722
# 2018-01-04 -0.007502  0.006305  0.036899  0.004645 -0.005703 -0.002225
# 2018-01-05  0.015988 -0.000380  0.010630  0.011385  0.017408  0.012104
# 2018-01-08  0.002146 -0.009877 -0.007042 -0.003714 -0.016022  0.016576
# 2018-01-09  0.024554 -0.000959 -0.008080 -0.000115  0.007538  0.006398
#
#                  ABT      ACGL       ACN      ADBE  ...       XYL       YUM  \
# Date                                                ...
# 2018-01-03  0.002211  0.000906  0.004615  0.018796  ...  0.012194 -0.000858
# 2018-01-04 -0.001697  0.003734  0.011841  0.012042  ...  0.006676  0.010180
# 2018-01-05  0.002890 -0.003945  0.008249  0.011571  ... -0.001874  0.005828
# 2018-01-08 -0.002882  0.000113  0.007991 -0.001619  ...  0.003611  0.001690
# 2018-01-09  0.001700 -0.012900  0.003335  0.008971  ...  0.000288 -0.002651
#
#                  ZBH      ZBRA      ZION       ZTS  Mkt-RF     SMB     HML  \
# Date
# 2018-01-03  0.006932  0.019863 -0.001183  0.004598  0.0059 -0.0039 -0.0019
# 2018-01-04 -0.001441  0.019760  0.004147  0.005964  0.0042 -0.0026  0.0025
# 2018-01-05  0.009941  0.015576  0.000393  0.011444  0.0066 -0.0035 -0.0025
# 2018-01-08  0.001905  0.009951 -0.004915  0.011996  0.0019 -0.0015  0.0004
# 2018-01-09 -0.016083  0.030643  0.023509  0.011719  0.0015 -0.0035 -0.0004
#
#                RF-%
# Date
# 2018-01-03  0.00006
# 2018-01-04  0.00006
# 2018-01-05  0.00006
# 2018-01-08  0.00006
# 2018-01-09  0.00006
#
# [5 rows x 494 columns]

# %%
bc_analysis = analysis.loc[analysis.index < datetime(2020, 2, 1)] #data before COVID-19
ac_analysis = analysis.loc[analysis.index > datetime(2020, 4, 30)] #data after COVID-19

# %% [markdown]
# #Fama-French model evaluation

# %% [markdown]
# ##Before COVID-19

# %%
# determine beta vector as well as residuals for each company
tickers = list(returns.columns)
bc_residuals = pd.DataFrame(columns = tickers)
bc_models = dict()
bc_betas = pd.DataFrame(columns = ['Mkt-RF', 'SMB', 'HML'])
bc_X = bc_analysis[['Mkt-RF', 'SMB', 'HML']]
bc_X = sm.add_constant(bc_X)

# %%
for company in tickers: #estimate regression models for each company
    bc_y = bc_analysis[company] - bc_analysis['RF-%']
    bc_model = sm.OLS(bc_y, bc_X).fit()
    bc_models[company] = bc_model
    bc_betas.loc[company, :] = bc_model.params[1:].values
    bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# Out:
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# ...
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)
# <ipython-input-14-97c8cb58b052>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   bc_residuals.loc[:, company] = bc_y - bc_model.predict(bc_X)

# %%
# examine the distribution for each beta factor over all companies

fig, axs = plt.subplots(1, 3, figsize = (12, 5))
bc_betas.loc[:, 'Mkt-RF'].hist(ax = axs[0])
axs[0].set_title(r'$beta_{r_m}$')
bc_betas.loc[:, 'SMB'].hist(ax = axs[1])
axs[1].set_title(r'$beta_{smb}$')
bc_betas.loc[:, 'HML'].hist(ax = axs[2])
axs[2].set_title(r'$beta_{hml}$')
plt.show()

# %% [markdown]
# ##After COVID-19

# %%
# determine beta vector as well as residuals for each company

ac_residuals = pd.DataFrame(columns = tickers)
ac_models = dict()
ac_betas = pd.DataFrame(columns = ['Mkt-RF', 'SMB', 'HML'])
ac_X = ac_analysis[['Mkt-RF', 'SMB', 'HML']]
ac_X = sm.add_constant(ac_X)

# %%
for company in tickers: #estimate regression models for each company
    ac_y = ac_analysis[company] - ac_analysis['RF-%']
    ac_model = sm.OLS(ac_y, ac_X).fit()
    ac_models[company] = ac_model
    ac_betas.loc[company, :] = ac_model.params[1:].values
    ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# Out:
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# ...
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)
# <ipython-input-17-dd25435a18de>:6: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   ac_residuals.loc[:, company] = ac_y - ac_model.predict(ac_X)

# %%
# examine the distribution for each beta factor over all companies

fig, axs = plt.subplots(1, 3, figsize = (12, 5))
ac_betas.loc[:, 'Mkt-RF'].hist(ax = axs[0])
axs[0].set_title(r'$beta_{r_m}$')
ac_betas.loc[:, 'SMB'].hist(ax = axs[1])
axs[1].set_title(r'$beta_{smb}$')
ac_betas.loc[:, 'HML'].hist(ax = axs[2])
axs[2].set_title(r'$beta_{hml}$')
plt.show()

# %% [markdown]
# ##Comparison

# %%
bc_betas.columns = ['Beta Mkt-RF', 'Beta SMB', 'Beta HML'] #rename columns
ac_betas.columns = ['Beta Mkt-RF', 'Beta SMB', 'Beta HML'] #rename columns
print(bc_betas, ac_betas)
# Out:
#      Beta Mkt-RF  Beta SMB  Beta HML
# A       1.104099 -0.008052 -0.232202
# AAL     1.467816   0.59704  0.379124
# AAP     0.786409  0.386944  0.296801
# AAPL    1.293202 -0.126728 -0.430565
# ABBV    1.015654  -0.24661 -0.118949
# ...          ...       ...       ...
# YUM     0.592636 -0.562231 -0.228679
# ZBH     0.855192 -0.012141 -0.248675
# ZBRA    1.306125  1.041292 -0.432578
# ZION    1.171605  0.531263   1.36043
# ZTS     0.909259  -0.24298 -0.486723
#
# [490 rows x 3 columns]      Beta Mkt-RF  Beta SMB  Beta HML
# A       0.933991 -0.054032 -0.229389
# AAL     1.591107  1.198248  1.145413
# AAP     0.853295  0.065554   0.27338
# AAPL    1.230291  -0.41886 -0.365256
# ABBV    0.467135 -0.361466  0.065246
# ...          ...       ...       ...
# YUM     0.724541 -0.117019  0.155665
# ZBH     0.940769  0.168168  0.319699
# ZBRA    1.335777  0.123236 -0.082555
# ZION    1.381653  0.605859  1.356046
# ZTS     0.866501 -0.379274 -0.261996
#
# [490 rows x 3 columns]

# %% [markdown]
# #Cluster analysis

# %% [markdown]
# ##Optimal number of clusters

# %%
#Standardize data
st_bc_betas = preprocessing.StandardScaler().fit_transform(bc_betas)
st_bc_betas = pd.DataFrame(st_bc_betas, columns = bc_betas.columns.values, index = bc_betas.index.values)

st_ac_betas = preprocessing.StandardScaler().fit_transform(ac_betas)
st_ac_betas = pd.DataFrame(st_ac_betas, columns = ac_betas.columns.values, index = ac_betas.index.values)

# %%
#Elbow criterion for hierarchical clustering before COVID-19
random.seed(108448)
model_hier = AgglomerativeClustering(metric = 'euclidean', linkage = 'ward')

# For data before COVID-19
visualizer_hier = KElbowVisualizer(model_hier, k=(2,30), timings = False)
visualizer_hier.fit(st_bc_betas)
visualizer_hier.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
#Silhouette coefficient
visualizer_hier = KElbowVisualizer(model_hier, k=(2,30), timings = False, metric='silhouette')
visualizer_hier.fit(st_bc_betas)
visualizer_hier.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
#Calinski-Harabasz Index
visualizer_hier = KElbowVisualizer(model_hier, k=(2,30), timings = False, metric = 'calinski_harabasz')
visualizer_hier.fit(st_bc_betas)
visualizer_hier.show()
# Out:
# <Axes: title={'center': 'Calinski Harabasz Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %%
#Elbow criterion
# For data after COVID-19
visualizer_hier = KElbowVisualizer(model_hier, k=(2, 30), timings = False)
visualizer_hier.fit(st_ac_betas)
visualizer_hier.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
#Silhouette coefficient
visualizer_hier = KElbowVisualizer(model_hier, k=(2, 30), timings = False, metric='silhouette')
visualizer_hier.fit(st_ac_betas)
visualizer_hier.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
visualizer_hier = KElbowVisualizer(model_hier, k=(2, 30), timings = False, metric ='calinski_harabasz')
visualizer_hier.fit(st_ac_betas)
visualizer_hier.show()
# Out:
# <Axes: title={'center': 'Calinski Harabasz Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %%
#Elbow criterion for k-means
random.seed(108448)
model_kmeans = KMeans(n_init = 'auto')

#For data before COVID-19
visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False)
visualizer.fit(st_bc_betas)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False, metric='silhouette')
visualizer.fit(st_bc_betas)
visualizer.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False, metric='calinski_harabasz')
visualizer.fit(st_bc_betas)
visualizer.show()
# Out:
# <Axes: title={'center': 'Calinski Harabasz Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %%
#For data after COVID-19
random.seed(108448)
visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False)
visualizer.fit(st_ac_betas)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False, metric='silhouette')
visualizer.fit(st_ac_betas)
visualizer.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False, metric='calinski_harabasz')
visualizer.fit(st_ac_betas)
visualizer.show()
# Out:
# <Axes: title={'center': 'Calinski Harabasz Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %% [markdown]
# ##Before COVID-19

# %% [markdown]
# ###Hierarchical clustering

# %%
#Hierarchical clustering

random.seed(108448)

k = 2
bc_hier = AgglomerativeClustering(n_clusters = k, metric = 'euclidean', linkage = 'ward')
bc_betas['Hier'] = bc_hier.fit_predict(st_bc_betas[['Beta HML', 'Beta Mkt-RF', 'Beta SMB']])
pd.pivot_table(bc_betas, index=['Hier'], values=['Beta Mkt-RF', 'Beta SMB', 'Beta HML'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
#           mean                             std
#       Beta HML Beta Mkt-RF  Beta SMB  Beta HML Beta Mkt-RF  Beta SMB
# Hier
# 0    -0.226823    0.771323 -0.102258  0.368279    0.352117  0.292305
# 1     0.550136    1.171352  0.315973  0.409519    0.227364  0.271088

# %%
#Visualizing hierarchical clustering

x = bc_betas['Beta Mkt-RF']
y = bc_betas['Beta SMB']
z = bc_betas['Beta HML']

cmap = colors.ListedColormap(['#0079FF', '#00DFA2', '#F6FA70', '#FF0060']) #define colors

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x, y, z, s = 40, c = bc_betas['Hier'], cmap = cmap )
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("Hierarchical Clustering, k = 2")
plt.show()

# %% [markdown]
# ###K-means

# %%
random.seed(108448)

bc_kmeans = KMeans(n_clusters = k, n_init = 'auto')
bc_kmeans.fit(st_bc_betas[['Beta HML', 'Beta Mkt-RF', 'Beta SMB']])
bc_betas['K-means'] = bc_kmeans.labels_
pd.pivot_table(bc_betas, index=['K-means'], values=['Beta Mkt-RF', 'Beta SMB', 'Beta HML'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
#              mean                             std
#          Beta HML Beta Mkt-RF  Beta SMB  Beta HML Beta Mkt-RF  Beta SMB
# K-means
# 0       -0.218844    0.704871 -0.166733  0.351739    0.317207  0.232641
# 1        0.397947    1.170823  0.309905  0.526490    0.238222  0.279822

# %%
#Visualizing k-means clustering

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x, y, z, s = 40, c = bc_betas['K-means'], cmap = cmap )
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("k-means Clustering, k = 2")
plt.show()

# %% [markdown]
# ###HDBSCAN

# %%
random.seed(108448)

bc_hdbscan = hdbscan.HDBSCAN()
bc_hdbscan.fit(st_bc_betas)
bc_betas['HDBSCAN'] = bc_hdbscan.labels_
pd.pivot_table(bc_betas, index=['HDBSCAN'], values=['Beta Mkt-RF', 'Beta SMB', 'Beta HML'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
#              mean                             std
#          Beta HML Beta Mkt-RF  Beta SMB  Beta HML Beta Mkt-RF  Beta SMB
# HDBSCAN
# -1       0.154085    1.142366  0.214861  0.813529    0.376473  0.436504
#  0       1.017085    1.320570 -0.022223  0.100035    0.077982  0.066096
#  1       0.018322    0.835848  0.005306  0.365897    0.324311  0.298305

# %%
x1 = bc_betas.drop(bc_betas[bc_betas['HDBSCAN'] == -1].index)['Beta Mkt-RF']
y1 = bc_betas.drop(bc_betas[bc_betas['HDBSCAN'] == -1].index)['Beta SMB']
z1 = bc_betas.drop(bc_betas[bc_betas['HDBSCAN'] == -1].index)['Beta HML']
c1 = bc_betas[bc_betas['HDBSCAN'] != -1]['HDBSCAN']

x2 = bc_betas[bc_betas['HDBSCAN'] == -1]['Beta Mkt-RF']
y2 = bc_betas[bc_betas['HDBSCAN'] == -1]['Beta SMB']
z2 = bc_betas[bc_betas['HDBSCAN'] == -1]['Beta HML']
c2 = bc_betas[bc_betas['HDBSCAN'] == -1]['HDBSCAN']

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x1, y1, z1, s = 40, c = c1, cmap = cmap)
ax.scatter(x2, y2, z2, s = 40, c = c2, cmap = colors.ListedColormap(['#A0A0A0']))
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("HDBSCAN Clustering")
plt.show()

# %% [markdown]
# ##After COVID-19

# %% [markdown]
# ###Hierarchical clustering

# %%
random.seed(108448)

#Hierarchical clustering with k = 2

ac_hier = AgglomerativeClustering(n_clusters = k, metric = 'euclidean', linkage = 'ward')
ac_betas['Hier'] = ac_hier.fit_predict(st_ac_betas[['Beta HML', 'Beta Mkt-RF', 'Beta SMB']])
pd.pivot_table(ac_betas, index=['Hier'], values=['Beta Mkt-RF', 'Beta SMB', 'Beta HML'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
#           mean                             std
#       Beta HML Beta Mkt-RF  Beta SMB  Beta HML Beta Mkt-RF  Beta SMB
# Hier
# 0    -0.039617    0.840270 -0.129949  0.340607    0.300376  0.268636
# 1     0.694714    1.162713  0.367665  0.370050    0.240040  0.298422

# %%
#Visualizing hierarchical clustering

x = ac_betas['Beta Mkt-RF']
y = ac_betas['Beta SMB']
z = ac_betas['Beta HML']

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x, y, z, s = 40, c = ac_betas['Hier'], cmap = cmap )
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("Hierarchical Clustering, k = 2")
plt.show()

# %% [markdown]
# ###K-means clustering

# %%
random.seed(108448)

ac_kmeans = KMeans(n_clusters = k, n_init = 'auto')
ac_kmeans.fit(st_ac_betas[['Beta HML', 'Beta Mkt-RF', 'Beta SMB']])
ac_betas['K-means'] = ac_kmeans.labels_
pd.pivot_table(ac_betas, index=['K-means'], values=['Beta Mkt-RF', 'Beta SMB', 'Beta HML'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
#              mean                             std
#          Beta HML Beta Mkt-RF  Beta SMB  Beta HML Beta Mkt-RF  Beta SMB
# K-means
# 0        0.653370    1.240935  0.437837  0.490948    0.223308  0.301749
# 1        0.036305    0.811512 -0.141764  0.345193    0.250242  0.200555

# %%
#Visualizing k-means clustering

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x, y, z, s = 40, c = ac_betas['K-means'], cmap = cmap )
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("k-means Clustering, k = 2")
plt.show()

# %% [markdown]
# ###HDBSCAN

# %%
ac_hdbscan = hdbscan.HDBSCAN()
ac_hdbscan.fit(st_ac_betas)
ac_betas['HDBSCAN'] = ac_hdbscan.labels_
pd.pivot_table(ac_betas, index=['HDBSCAN'], values=['Beta Mkt-RF', 'Beta SMB', 'Beta HML'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
#              mean                             std
#          Beta HML Beta Mkt-RF  Beta SMB  Beta HML Beta Mkt-RF  Beta SMB
# HDBSCAN
# -1       0.162891    1.283918  0.448601  0.758522    0.361862  0.477299
#  0       0.323732    0.907221  0.011233  0.413782    0.265722  0.296482
#  1      -0.606215    1.216026 -0.181668  0.115400    0.051216  0.132399

# %%
x1 = ac_betas.drop(ac_betas[ac_betas['HDBSCAN'] == -1].index)['Beta Mkt-RF']
y1 = ac_betas.drop(ac_betas[ac_betas['HDBSCAN'] == -1].index)['Beta SMB']
z1 = ac_betas.drop(ac_betas[ac_betas['HDBSCAN'] == -1].index)['Beta HML']
c1 = ac_betas[ac_betas['HDBSCAN'] != -1]['HDBSCAN']

x2 = ac_betas[ac_betas['HDBSCAN'] == -1]['Beta Mkt-RF']
y2 = ac_betas[ac_betas['HDBSCAN'] == -1]['Beta SMB']
z2 = ac_betas[ac_betas['HDBSCAN'] == -1]['Beta HML']
c2 = ac_betas[ac_betas['HDBSCAN'] == -1]['HDBSCAN']

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x1, y1, z1, s = 40, c = c1, cmap = cmap)
ax.scatter(x2, y2, z2, s = 40, c = c2, cmap = colors.ListedColormap(['#A0A0A0']))
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("HDBSCAN Clustering")
plt.show()

# %% [markdown]
# ##Clusters comparison

# %%
#Add companies names and industries
bc_betas.index.name  = 'Symbol'
bc_betas = pd.merge(bc_betas,
                    companies[['Security', 'GICS Sector', 'GICS Sub-Industry']],
                     how ='left', on = 'Symbol')

ac_betas.index.name  = 'Symbol'
ac_betas = pd.merge(ac_betas,
                    companies[['Security', 'GICS Sector', 'GICS Sub-Industry']],
                     how ='left', on = 'Symbol')

#For pivot
bc_betas['Ticker'] = bc_betas.index
ac_betas['Ticker'] = ac_betas.index

# %% [markdown]
# ###Similarities between clusters

# %% [markdown]
# ####Adjusted rand score

# %%
methods = ['K-means', 'HDBSCAN', 'Hier']
adjrandscore = pd.DataFrame(columns = methods, index = methods)

print('Adjusted rand score before COVID-19:')
for i in methods:
  for j in methods:
    adjrandscore.loc[i, j] = adjusted_rand_score(bc_betas[i], bc_betas[j])

adjrandscore
# Out:
# Adjusted rand score before COVID-19:
#           K-means   HDBSCAN      Hier
# K-means       1.0  0.046294  0.639258
# HDBSCAN  0.046294       1.0  0.063061
# Hier     0.639258  0.063061       1.0

# %%
print('Adjusted rand score after COVID-19:')
for i in methods:
  for j in methods:
    adjrandscore.loc[i, j] = adjusted_rand_score(ac_betas[i], ac_betas[j])

adjrandscore
# Out:
# Adjusted rand score after COVID-19:
#           K-means   HDBSCAN      Hier
# K-means       1.0   0.07655  0.568988
# HDBSCAN   0.07655       1.0  0.000905
# Hier     0.568988  0.000905       1.0

# %%
print('Adjusted rand score before vs. after COVID-19:')
for i in methods:
  for j in methods:
    adjrandscore.loc[i, j] = adjusted_rand_score(bc_betas[i], ac_betas[j])

adjrandscore
# Out:
# Adjusted rand score before vs. after COVID-19:
#           K-means   HDBSCAN      Hier
# K-means  0.297697  0.037947  0.254634
# HDBSCAN  0.090326  0.188161  0.020303
# Hier     0.387409  0.037262  0.358189

# %% [markdown]
# ####Intersection tables

# %%
similarity = pd.DataFrame(columns = range(k), index = range(k))

for i in range(k):
  for j in range(k):
    similarity.loc[i, j] = len(pd.merge(bc_betas.loc[bc_betas['K-means'] == i], bc_betas.loc[bc_betas['Hier'] == j], how ='inner', on = 'Ticker'))

print('Similarities between K-means clusters (index) and hierarchical clusters (columns) before COVID-19')
similarity
# Out:
# Similarities between K-means clusters (index) and hierarchical clusters (columns) before COVID-19
#      0    1
# 0  254    3
# 1   46  187

# %%
similarity = pd.DataFrame(columns = range(k), index = range(k))

for i in range(k):
  for j in range(k):
    similarity.loc[i, j] = len(pd.merge(ac_betas.loc[ac_betas['K-means'] == i], ac_betas.loc[ac_betas['Hier'] == j], how ='inner', on = 'Ticker'))

print('Similarities between K-means clusters (index) and hierarchical clusters (columns) after COVID-19')
similarity
# Out:
# Similarities between K-means clusters (index) and hierarchical clusters (columns) after COVID-19
#      0    1
# 0   20  172
# 1  258   40

# %%
similarity = pd.DataFrame(columns = range(k), index = range(k))

for i in range(k):
  for j in range(k):
    similarity.loc[i, j] = len(pd.merge(bc_betas.loc[bc_betas['Hier'] == i], ac_betas.loc[ac_betas['Hier'] == j], how ='inner', on = 'Ticker'))

print('Similarities between hierarchical clusters before COVID (index) and after COVID (columns)')
similarity
# Out:
# Similarities between hierarchical clusters before COVID (index) and after COVID (columns)
#      0    1
# 0  240   60
# 1   38  152

# %%
similarity = pd.DataFrame(columns = range(k), index = range(k))

for i in range(k):
  for j in range(k):
    similarity.loc[i, j] = len(pd.merge(bc_betas.loc[bc_betas['K-means'] == i], ac_betas.loc[ac_betas['K-means'] == j], how ='inner', on = 'Ticker'))

print('Similarities between K-means clusters before COVID (index) and after COVID (columns)')
similarity
# Out:
# Similarities between K-means clusters before COVID (index) and after COVID (columns)
#      0    1
# 0   35  222
# 1  157   76

# %%
v = [-1, 0, 1]
similarity = pd.DataFrame(columns = v, index = v)

for i in v:
  for j in v:
    similarity.loc[i, j] = len(pd.merge(bc_betas.loc[bc_betas['HDBSCAN'] == i], ac_betas.loc[ac_betas['HDBSCAN'] == j], how ='inner', on = 'Ticker'))

print('Similarities between HDBSCAN clusters before COVID (index) and after COVID (columns)')
similarity
# Out:
# Similarities between HDBSCAN clusters before COVID (index) and after COVID (columns)
#     -1    0  1
# -1  49   75  5
#  0   1    9  0
#  1  37  310  4

# %% [markdown]
# ###Industries analysis

# %%
total = bc_betas.merge(ac_betas, on = ['Ticker', 'GICS Sector', 'GICS Sub-Industry', 'Security'])
total.head()
# Out:
#   Beta Mkt-RF_x Beta SMB_x Beta HML_x  Hier_x  K-means_x  HDBSCAN_x  \
# 0      1.104099  -0.008052  -0.232202       0          0          1
# 1      1.467816    0.59704   0.379124       1          1         -1
# 2      0.786409   0.386944   0.296801       1          1          1
# 3      1.293202  -0.126728  -0.430565       0          0         -1
# 4      1.015654   -0.24661  -0.118949       0          0          1
#
#                   Security             GICS Sector  \
# 0     Agilent Technologies             Health Care
# 1  American Airlines Group             Industrials
# 2       Advance Auto Parts  Consumer Discretionary
# 3               Apple Inc.  Information Technology
# 4                   AbbVie             Health Care
#
#                             GICS Sub-Industry Ticker Beta Mkt-RF_y Beta SMB_y  \
# 0                       Health Care Equipment      A      0.933991  -0.054032
# 1                          Passenger Airlines    AAL      1.591107   1.198248
# 2                           Automotive Retail    AAP      0.853295   0.065554
# 3  Technology Hardware, Storage & Peripherals   AAPL      1.230291   -0.41886
# 4                             Pharmaceuticals   ABBV      0.467135  -0.361466
#
#   Beta HML_y  Hier_y  K-means_y  HDBSCAN_y
# 0  -0.229389       0          1          0
# 1   1.145413       1          0         -1
# 2    0.27338       1          1          0
# 3  -0.365256       0          1          1
# 4   0.065246       0          1          0

# %%
print('Industries distribution before COVID, K-means')
pd.pivot_table(bc_betas, columns=['K-means'], index = ['GICS Sector'], values = ['Ticker'], aggfunc = pd.Series.nunique)
# Out:
# Industries distribution before COVID, K-means
#                        Ticker
# K-means                     0     1
# GICS Sector
# Communication Services   15.0   6.0
# Consumer Discretionary   18.0  35.0
# Consumer Staples         32.0   4.0
# Energy                    NaN  23.0
# Financials               35.0  36.0
# Health Care              44.0  18.0
# Industrials              19.0  53.0
# Information Technology   28.0  38.0
# Materials                11.0  16.0
# Real Estate              27.0   3.0
# Utilities                28.0   1.0

# %%
print('Industries distribution after COVID, K-means')
pd.pivot_table(ac_betas, columns=['K-means'], index = ['GICS Sector'], values = ['Ticker'], aggfunc = pd.Series.nunique)
# Out:
# Industries distribution after COVID, K-means
#                        Ticker
# K-means                     0     1
# GICS Sector
# Communication Services    9.0  12.0
# Consumer Discretionary   33.0  20.0
# Consumer Staples          2.0  34.0
# Energy                   23.0   NaN
# Financials               42.0  29.0
# Health Care               4.0  58.0
# Industrials              28.0  44.0
# Information Technology   26.0  40.0
# Materials                14.0  13.0
# Real Estate              10.0  20.0
# Utilities                 1.0  28.0

# %%
pd.pivot_table(ac_betas.loc[ac_betas['Hier'] == 0], columns=['K-means', 'Hier'],
                    index = ['GICS Sector', 'GICS Sub-Industry'], values = ['Beta HML'], aggfunc = ['mean', pd.Series.nunique])
# Out:
#                                                                   mean  \
#                                                               Beta HML
# K-means                                                              0
# Hier                                                                 0
# GICS Sector            GICS Sub-Industry
# Communication Services Cable & Satellite                           NaN
#                        Integrated Telecommunication Services       NaN
#                        Interactive Home Entertainment              NaN
#                        Interactive Media & Services          -0.560633
#                        Movies & Entertainment                      NaN
# ...                                                                ...
# Real Estate            Telecom Tower REITs                         NaN
# Utilities              Electric Utilities                          NaN
#                        Gas Utilities                               NaN
#                        Multi-Utilities                             NaN
#                        Water Utilities                             NaN
#
#                                                                         \
#
# K-means                                                              1
# Hier                                                                 0
# GICS Sector            GICS Sub-Industry
# Communication Services Cable & Satellite                      0.023205
#                        Integrated Telecommunication Services  0.360047
#                        Interactive Home Entertainment        -0.399518
#                        Interactive Media & Services          -0.372366
#                        Movies & Entertainment                -0.771970
# ...                                                                ...
# Real Estate            Telecom Tower REITs                   -0.187079
# Utilities              Electric Utilities                     0.257328
#                        Gas Utilities                          0.317200
#                        Multi-Utilities                        0.227105
#                        Water Utilities                       -0.079897
#
#                                                               nunique
#                                                              Beta HML
# K-means                                                             0     1
# Hier                                                                0     0
# GICS Sector            GICS Sub-Industry
# Communication Services Cable & Satellite                          NaN   2.0
#                        Integrated Telecommunication Services      NaN   2.0
#                        Interactive Home Entertainment             NaN   3.0
#                        Interactive Media & Services               1.0   3.0
#                        Movies & Entertainment                     NaN   1.0
# ...                                                               ...   ...
# Real Estate            Telecom Tower REITs                        NaN   3.0
# Utilities              Electric Utilities                         NaN  13.0
#                        Gas Utilities                              NaN   1.0
#                        Multi-Utilities                            NaN  12.0
#                        Water Utilities                            NaN   1.0
#
# [78 rows x 4 columns]

# %%
pd.pivot_table(ac_betas.loc[ac_betas['GICS Sector'] == 'Consumer Discretionary'], columns=['K-means', 'Hier'],
                    index = ['GICS Sector', 'GICS Sub-Industry'], values = ['Beta HML'], aggfunc = ['mean', pd.Series.nunique])
# Out:
#                                                                mean            \
#                                                            Beta HML
# K-means                                                           0
# Hier                                                              0         1
# GICS Sector            GICS Sub-Industry
# Consumer Discretionary Apparel Retail                           NaN  0.389211
#                        Apparel, Accessories & Luxury Goods      NaN  0.673746
#                        Automobile Manufacturers            -0.79148  0.693017
#                        Automotive Parts & Equipment             NaN  0.524700
#                        Automotive Retail                        NaN  0.204689
#                        Casinos & Gaming                         NaN  0.558785
#                        Computer & Electronics Retail            NaN  0.078762
#                        Consumer Electronics                     NaN       NaN
#                        Distributors                             NaN  0.615483
#                        Home Furnishings                         NaN  0.720833
#                        Home Improvement Retail                  NaN       NaN
#                        Homebuilding                             NaN  0.011840
#                        Hotels, Resorts & Cruise Lines           NaN  0.935226
#                        Household Appliances                     NaN  0.225725
#                        Housewares & Specialties                 NaN  0.632748
#                        Internet & Direct Marketing Retail       NaN  0.498854
#                        Leisure Products                         NaN       NaN
#                        Restaurants                              NaN  0.497183
#                        Specialty Stores                         NaN  0.456385
#
#                                                                       \
#
# K-means                                                            1
# Hier                                                               0
# GICS Sector            GICS Sub-Industry
# Consumer Discretionary Apparel Retail                            NaN
#                        Apparel, Accessories & Luxury Goods -0.012662
#                        Automobile Manufacturers                  NaN
#                        Automotive Parts & Equipment              NaN
#                        Automotive Retail                         NaN
#                        Casinos & Gaming                          NaN
#                        Computer & Electronics Retail             NaN
#                        Consumer Electronics                 0.038413
#                        Distributors                        -0.430089
#                        Home Furnishings                          NaN
#                        Home Improvement Retail             -0.074539
#                        Homebuilding                              NaN
#                        Hotels, Resorts & Cruise Lines            NaN
#                        Household Appliances                      NaN
#                        Housewares & Specialties                  NaN
#                        Internet & Direct Marketing Retail  -0.726050
#                        Leisure Products                          NaN
#                        Restaurants                         -0.095914
#                        Specialty Stores                     0.028365
#
#                                                                       nunique  \
#                                                                      Beta HML
# K-means                                                                     0
# Hier                                                               1        0
# GICS Sector            GICS Sub-Industry
# Consumer Discretionary Apparel Retail                            NaN      NaN
#                        Apparel, Accessories & Luxury Goods       NaN      NaN
#                        Automobile Manufacturers                  NaN      1.0
#                        Automotive Parts & Equipment              NaN      NaN
#                        Automotive Retail                    0.273380      NaN
#                        Casinos & Gaming                          NaN      NaN
#                        Computer & Electronics Retail             NaN      NaN
#                        Consumer Electronics                      NaN      NaN
#                        Distributors                              NaN      NaN
#                        Home Furnishings                          NaN      NaN
#                        Home Improvement Retail                   NaN      NaN
#                        Homebuilding                         0.084555      NaN
#                        Hotels, Resorts & Cruise Lines            NaN      NaN
#                        Household Appliances                      NaN      NaN
#                        Housewares & Specialties                  NaN      NaN
#                        Internet & Direct Marketing Retail        NaN      NaN
#                        Leisure Products                     0.316316      NaN
#                        Restaurants                               NaN      NaN
#                        Specialty Stores                     0.544630      NaN
#
#
#
# K-means                                                            1
# Hier                                                          1    0    1
# GICS Sector            GICS Sub-Industry
# Consumer Discretionary Apparel Retail                       2.0  NaN  NaN
#                        Apparel, Accessories & Luxury Goods  3.0  1.0  NaN
#                        Automobile Manufacturers             2.0  NaN  NaN
#                        Automotive Parts & Equipment         2.0  NaN  NaN
#                        Automotive Retail                    1.0  NaN  1.0
#                        Casinos & Gaming                     4.0  NaN  NaN
#                        Computer & Electronics Retail        1.0  NaN  NaN
#                        Consumer Electronics                 NaN  1.0  NaN
#                        Distributors                         1.0  1.0  NaN
#                        Home Furnishings                     1.0  NaN  NaN
#                        Home Improvement Retail              NaN  2.0  NaN
#                        Homebuilding                         3.0  NaN  1.0
#                        Hotels, Resorts & Cruise Lines       5.0  NaN  NaN
#                        Household Appliances                 1.0  NaN  NaN
#                        Housewares & Specialties             1.0  NaN  NaN
#                        Internet & Direct Marketing Retail   2.0  3.0  NaN
#                        Leisure Products                     NaN  NaN  1.0
#                        Restaurants                          1.0  5.0  NaN
#                        Specialty Stores                     2.0  3.0  1.0

# %%
# df = pd.pivot_table(bc_betas, index = ['K-means', 'GICS Sector', 'GICS Sub-Industry'], values = ['Ticker'], aggfunc = pd.Series.nunique)
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     print(df)

# %%
# df = pd.pivot_table(total, columns=['K-means_x', 'K-means_y'], index = ['GICS Sector', 'GICS Sub-Industry'], values = ['Ticker'], aggfunc = pd.Series.nunique)
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#      print(df)

# %% [markdown]
# #Appendix

# %% [markdown]
# ##Analysis of changers

# %% [markdown]
# ###Beta differences

# %%
#Create differences of betas
total['Beta Mkt-RF Diff'] = total['Beta Mkt-RF_y'] - total['Beta Mkt-RF_x']
total['Beta SMB Diff'] =  total['Beta SMB_y'] - total['Beta SMB_x']
total['Beta HML Diff'] = total['Beta HML_y'] - total['Beta HML_x']
total.head()
# Out:
#   Beta Mkt-RF_x Beta SMB_x Beta HML_x  Hier_x  K-means_x  HDBSCAN_x  \
# 0      1.104099  -0.008052  -0.232202       0          0          1
# 1      1.467816    0.59704   0.379124       1          1         -1
# 2      0.786409   0.386944   0.296801       1          1          1
# 3      1.293202  -0.126728  -0.430565       0          0         -1
# 4      1.015654   -0.24661  -0.118949       0          0          1
#
#                   Security             GICS Sector  \
# 0     Agilent Technologies             Health Care
# 1  American Airlines Group             Industrials
# 2       Advance Auto Parts  Consumer Discretionary
# 3               Apple Inc.  Information Technology
# 4                   AbbVie             Health Care
#
#                             GICS Sub-Industry Ticker Beta Mkt-RF_y Beta SMB_y  \
# 0                       Health Care Equipment      A      0.933991  -0.054032
# 1                          Passenger Airlines    AAL      1.591107   1.198248
# 2                           Automotive Retail    AAP      0.853295   0.065554
# 3  Technology Hardware, Storage & Peripherals   AAPL      1.230291   -0.41886
# 4                             Pharmaceuticals   ABBV      0.467135  -0.361466
#
#   Beta HML_y  Hier_y  K-means_y  HDBSCAN_y Beta Mkt-RF Diff Beta SMB Diff  \
# 0  -0.229389       0          1          0        -0.170108      -0.04598
# 1   1.145413       1          0         -1         0.123292      0.601208
# 2    0.27338       1          1          0         0.066885     -0.321391
# 3  -0.365256       0          1          1         -0.06291     -0.292132
# 4   0.065246       0          1          0        -0.548519     -0.114855
#
#   Beta HML Diff
# 0      0.002813
# 1      0.766289
# 2     -0.023421
# 3      0.065309
# 4      0.184195

# %% [markdown]
# ###Optimal number of clusters

# %%
#Standardize data
st_total = preprocessing.StandardScaler().fit_transform(total[['Beta Mkt-RF Diff', 'Beta SMB Diff', 'Beta HML Diff']])
st_total = pd.DataFrame(st_total, columns = ['Beta Mkt-RF Diff', 'Beta SMB Diff', 'Beta HML Diff'], index = total.index.values)

# %%
#Elbow criterion for k-means
random.seed(108448)
model_kmeans = KMeans(n_init = 10)

visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False)
visualizer.fit(st_total)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False, metric = 'silhouette')
visualizer.fit(st_total)
visualizer.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
visualizer = KElbowVisualizer(model_kmeans, k = (2, 30), timings = False, metric = 'calinski_harabasz')
visualizer.fit(st_total)
visualizer.show()
# Out:
# <Axes: title={'center': 'Calinski Harabasz Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %%
#Elbow criterion
random.seed(108448)
model_hier = AgglomerativeClustering()

visualizer = KElbowVisualizer(model_hier, k = (2, 30), timings = False)
visualizer.fit(st_total)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
visualizer = KElbowVisualizer(model_hier, k = (2, 30), timings = False, metric = 'silhouette')
visualizer.fit(st_total)
visualizer.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
visualizer = KElbowVisualizer(model_hier, k = (2, 30), timings = False, metric = 'calinski_harabasz')
visualizer.fit(st_total)
visualizer.show()
# Out:
# <Axes: title={'center': 'Calinski Harabasz Score Elbow for AgglomerativeClustering Clustering'}, xlabel='k', ylabel='calinski harabasz score'>

# %% [markdown]
# ###K-means

# %%
#K-means
random.seed(108448)

k2 = 2

diff_kmeans = KMeans(n_clusters = k2)
diff_kmeans.fit(st_total)
total['K-means_z'] = diff_kmeans.labels_
pd.pivot_table(total, index=['K-means_z'], values=['Beta Mkt-RF Diff', 'Beta SMB Diff', 'Beta HML Diff'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#                    mean                                          std  \
#           Beta HML Diff Beta Mkt-RF Diff Beta SMB Diff Beta HML Diff
# K-means_z
# 0              0.466493         0.286128      0.227358      0.266987
# 1              0.038604        -0.092830     -0.101359      0.253877
#
#
#           Beta Mkt-RF Diff Beta SMB Diff
# K-means_z
# 0                 0.204703      0.252352
# 1                 0.180564      0.215276

# %%
x = total['Beta Mkt-RF Diff']
y = total['Beta SMB Diff']
z = total['Beta HML Diff']

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x, y, z, s = 40, c = total['K-means_z'], cmap = cmap )
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("K-means Diff Clustering")
plt.show()

# %% [markdown]
# ###Hierarchical clustering

# %%
#Hierarchical clustering

random.seed(108448)

diff_hier = AgglomerativeClustering(n_clusters = k2, metric = 'euclidean', linkage = 'ward')
total['Hier_z'] = diff_hier.fit_predict(st_total)
pd.pivot_table(total, index=['Hier_z'], values=['Beta Mkt-RF Diff', 'Beta SMB Diff', 'Beta HML Diff'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
#                 mean                                          std  \
#        Beta HML Diff Beta Mkt-RF Diff Beta SMB Diff Beta HML Diff
# Hier_z
# 0           0.307036         0.197711      0.183463      0.356137
# 1           0.065795        -0.139155     -0.185276      0.235827
#
#
#        Beta Mkt-RF Diff Beta SMB Diff
# Hier_z
# 0              0.225988      0.236165
# 1              0.175889      0.176940

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x, y, z, s = 40, c = total['Hier_z'], cmap = cmap )
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("Hierarchical Diff Clustering")
plt.show()

# %% [markdown]
# ###HDBSCAN

# %%
random.seed(108448)

diff_hdbscan = hdbscan.HDBSCAN()
diff_hdbscan.fit(st_total)
total['HDBSCAN_z'] = bc_hdbscan.labels_
pd.pivot_table(total, index=['HDBSCAN_z'], values=['Beta Mkt-RF Diff', 'Beta SMB Diff', 'Beta HML Diff'], aggfunc = ['mean', 'std']) #mean betas for each cluster
# Out:
#                    mean                                          std  \
#           Beta HML Diff Beta Mkt-RF Diff Beta SMB Diff Beta HML Diff
# HDBSCAN_z
# -1             0.127707         0.035359      0.005522      0.337550
#  0            -0.142936        -0.077645      0.232320      0.130488
#  1             0.241431         0.063680      0.026855      0.324301
#
#
#           Beta Mkt-RF Diff Beta SMB Diff
# HDBSCAN_z
# -1                0.233975      0.287945
#  0                0.144480      0.098084
#  1                0.277159      0.278984

# %%
x1 = total.drop(total[total['HDBSCAN_z'] == -1].index)['Beta Mkt-RF Diff']
y1 = total.drop(total[total['HDBSCAN_z'] == -1].index)['Beta SMB Diff']
z1 = total.drop(total[total['HDBSCAN_z'] == -1].index)['Beta HML Diff']
c1 = total[total['HDBSCAN_z'] != -1]['HDBSCAN_z']


x2 = total[total['HDBSCAN_z'] == -1]['Beta Mkt-RF Diff']
y2 = total[total['HDBSCAN_z'] == -1]['Beta SMB Diff']
z2 = total[total['HDBSCAN_z'] == -1]['Beta HML Diff']
c2 = total[total['HDBSCAN_z'] == -1]['HDBSCAN_z']

fig = plt.figure(figsize=(8,8))
ax = plt.subplot(111, projection = '3d')
ax.scatter(x1, y1, z1, s = 40, c = c1, cmap = cmap)
ax.scatter(x2, y2, z2, s = 40, c = c2, cmap = colors.ListedColormap(['#A0A0A0']))
ax.set_xlabel('BetaMkt-RF')
ax.set_ylabel('SMB')
ax.set_zlabel('HML')
ax.set_title("HDBSCAN Clustering")
plt.show()

# %% [markdown]
# ###Comparison

# %%
methods = ['K-means_z', 'HDBSCAN_z', 'Hier_z']
adjrandscore = pd.DataFrame(columns = methods, index = methods)

print('Adjusted rand score for beta differences:')
for i in methods:
  for j in methods:
    adjrandscore.loc[i, j] = adjusted_rand_score(total[i], total[j])

adjrandscore
# Out:
# Adjusted rand score for beta differences:
#           K-means_z HDBSCAN_z    Hier_z
# K-means_z       1.0 -0.016962  0.383077
# HDBSCAN_z -0.016962       1.0 -0.008327
# Hier_z     0.383077 -0.008327       1.0

# %%
similarity = pd.DataFrame(columns = range(k), index = range(k))

for i in range(k):
  for j in range(k):
    similarity.loc[i, j] = len(pd.merge(total.loc[total['K-means_z'] == i], total.loc[total['Hier_z'] == j], how ='inner', on = 'Ticker'))

print('Similarities between K-means clusters (index) and hierarchical clusters (columns) for beta differences')
similarity
# Out:
# Similarities between K-means clusters (index) and hierarchical clusters (columns) for beta differences
#      0    1
# 0  188    1
# 1   92  209

# %%
similarity = pd.DataFrame(columns = [-1, 0, 1], index = range(k))

for i in range(k):
  for j in [-1, 0, 1]:
    similarity.loc[i, j] = len(pd.merge(total.loc[total['K-means_z'] == i], total.loc[total['HDBSCAN_z'] == j], how ='inner', on = 'Ticker'))

print('Similarities between K-means clusters (index) and HDBSCAN (columns) for beta differences')
similarity
# Out:
# Similarities between K-means clusters (index) and HDBSCAN (columns) for beta differences
#    -1  0    1
# 0  40  1  148
# 1  89  9  203

# %%
similarity = pd.DataFrame(columns = [-1, 0, 1], index = range(k))

for i in range(k):
  for j in [-1, 0, 1]:
    similarity.loc[i, j] = len(pd.merge(total.loc[total['Hier_z'] == i], total.loc[total['HDBSCAN_z'] == j], how ='inner', on = 'Ticker'))

print('Similarities between Hierarchical clustering (index) and HDBSCAN (columns) for beta differences')
similarity
# Out:
# Similarities between Hierarchical clustering (index) and HDBSCAN (columns) for beta differences
#    -1   0    1
# 0  75  10  195
# 1  54   0  156

# %% [markdown]
# ###Industries analysis

# %%
pd.pivot_table(total, columns=['Hier_x', 'Hier_y'], index = ['GICS Sector'], values = ['Beta HML_x', 'Beta HML_y'], aggfunc = ['mean', pd.Series.nunique])
# Out:
#                              mean                                           \
#                        Beta HML_x                               Beta HML_y
# Hier_x                          0                   1                    0
# Hier_y                          0         1         0         1          0
# GICS Sector
# Communication Services  -0.458411  0.090913       NaN  0.375341  -0.221635
# Consumer Discretionary  -0.252347 -0.014167  0.089413  0.312590  -0.235603
# Consumer Staples         0.001879  0.108232  0.652451  0.486745   0.119501
# Energy                        NaN  0.347540       NaN  0.827071        NaN
# Financials              -0.150098  0.086704  0.439584  1.099416   0.076105
# Health Care             -0.365884  0.010360  0.295217  0.423947  -0.138442
# Industrials             -0.225472  0.014744  0.386899  0.466827   0.111136
# Information Technology  -0.547987 -0.133558  0.004398  0.185612  -0.356874
# Materials               -0.017480  0.039910       NaN  0.619132   0.150892
# Real Estate             -0.329512 -0.143604       NaN  0.175367  -0.012774
# Utilities               -0.187146 -0.080711  0.447205       NaN   0.234850
#
#                                                         nunique              \
#                                                      Beta HML_x
# Hier_x                                   1                    0           1
# Hier_y                         1         0         1          0     1     0
# GICS Sector
# Communication Services  0.559430       NaN  0.426022       13.0   4.0   NaN
# Consumer Discretionary  0.422381 -0.191739  0.536490       15.0   9.0   2.0
# Consumer Staples        0.688550  0.153680  0.628784       30.0   3.0   1.0
# Energy                  0.723041       NaN  1.223846        NaN   1.0   NaN
# Financials              0.661043  0.109027  1.008600       26.0   8.0   2.0
# Health Care             0.465130  0.353788  0.537495       52.0   4.0   4.0
# Industrials             0.372315  0.159682  0.611127       16.0   8.0  15.0
# Information Technology  0.248019 -0.162205  0.365981       39.0   5.0  13.0
# Materials               0.461333       NaN  0.709328        9.0   3.0   NaN
# Real Estate             0.634605       NaN  0.674542       14.0  13.0   NaN
# Utilities               0.289083  0.201723       NaN       26.0   2.0   1.0
#
#
#                              Beta HML_y
# Hier_x                                0           1
# Hier_y                     1          0     1     0     1
# GICS Sector
# Communication Services   4.0       13.0   4.0   NaN   4.0
# Consumer Discretionary  27.0       15.0   9.0   2.0  27.0
# Consumer Staples         2.0       30.0   3.0   1.0   2.0
# Energy                  22.0        NaN   1.0   NaN  22.0
# Financials              35.0       26.0   8.0   2.0  35.0
# Health Care              2.0       52.0   4.0   4.0   2.0
# Industrials             33.0       16.0   8.0  15.0  33.0
# Information Technology   9.0       39.0   5.0  13.0   9.0
# Materials               15.0        9.0   3.0   NaN  15.0
# Real Estate              3.0       14.0  13.0   NaN   3.0
# Utilities                NaN       26.0   2.0   1.0   NaN

# %%
pd.pivot_table(total.loc[total['Hier_z'] == 1], columns=['K-means_z'],
                    index = ['GICS Sector'], values = ['Beta Mkt-RF Diff', 'Beta SMB Diff', 'Beta HML Diff'], aggfunc = ['mean', pd.Series.nunique])
# Out:
#                                 mean                                       \
#                        Beta HML Diff           Beta Mkt-RF Diff
# K-means_z                          0         1                0         1
# GICS Sector
# Communication Services           NaN  0.193497              NaN -0.199956
# Consumer Discretionary           NaN -0.067488              NaN -0.087799
# Consumer Staples                 NaN  0.052063              NaN -0.052029
# Energy                           NaN  0.185496              NaN -0.110550
# Financials                       NaN  0.056437              NaN -0.066946
# Health Care                      NaN  0.119572              NaN -0.219358
# Industrials                 0.406932 -0.011677         0.202351 -0.164198
# Information Technology           NaN  0.087466              NaN -0.129296
# Materials                        NaN  0.079925              NaN -0.067292
# Utilities                        NaN -0.245482              NaN  0.176273
#
#                                                      nunique        \
#                        Beta SMB Diff           Beta HML Diff
# K-means_z                          0         1             0     1
# GICS Sector
# Communication Services           NaN -0.204947           NaN  11.0
# Consumer Discretionary           NaN -0.199699           NaN  14.0
# Consumer Staples                 NaN -0.118813           NaN  20.0
# Energy                           NaN -0.117566           NaN  10.0
# Financials                       NaN -0.102890           NaN   8.0
# Health Care                      NaN -0.236874           NaN  44.0
# Industrials                -0.154548 -0.188012           1.0  49.0
# Information Technology           NaN -0.191481           NaN  37.0
# Materials                        NaN -0.136261           NaN  15.0
# Utilities                        NaN -0.564478           NaN   1.0
#
#
#                        Beta Mkt-RF Diff       Beta SMB Diff
# K-means_z                             0     1             0     1
# GICS Sector
# Communication Services              NaN  11.0           NaN  11.0
# Consumer Discretionary              NaN  14.0           NaN  14.0
# Consumer Staples                    NaN  20.0           NaN  20.0
# Energy                              NaN  10.0           NaN  10.0
# Financials                          NaN   8.0           NaN   8.0
# Health Care                         NaN  44.0           NaN  44.0
# Industrials                         1.0  49.0           1.0  49.0
# Information Technology              NaN  37.0           NaN  37.0
# Materials                           NaN  15.0           NaN  15.0
# Utilities                           NaN   1.0           NaN   1.0

# %%
pd.pivot_table(total.loc[total['Hier_z'] == 1], columns=['K-means_z'],
                    index = ['GICS Sector', 'GICS Sub-Industry'], values = ['Ticker'], aggfunc = pd.Series.nunique)
# Out:
#                                                                       Ticker  \
# K-means_z                                                                  0
# GICS Sector            GICS Sub-Industry
# Communication Services Cable & Satellite                                 NaN
#                        Integrated Telecommunication Services             NaN
#                        Interactive Home Entertainment                    NaN
#                        Interactive Media & Services                      NaN
#                        Movies & Entertainment                            NaN
# ...                                                                      ...
# Materials              Fertilizers & Agricultural Chemicals              NaN
#                        Paper & Plastic Packaging Products & Materials    NaN
#                        Specialty Chemicals                               NaN
#                        Steel                                             NaN
# Utilities              Multi-Utilities                                   NaN
#
#
# K-means_z                                                                1
# GICS Sector            GICS Sub-Industry
# Communication Services Cable & Satellite                               2.0
#                        Integrated Telecommunication Services           1.0
#                        Interactive Home Entertainment                  3.0
#                        Interactive Media & Services                    3.0
#                        Movies & Entertainment                          1.0
# ...                                                                    ...
# Materials              Fertilizers & Agricultural Chemicals            2.0
#                        Paper & Plastic Packaging Products & Materials  4.0
#                        Specialty Chemicals                             5.0
#                        Steel                                           2.0
# Utilities              Multi-Utilities                                 1.0
#
# [75 rows x 2 columns]

# %%
# df = pd.pivot_table(total, index = ['GICS Sector', 'GICS Sub-Industry'], columns = 'K-means_z', values = ['Ticker'], aggfunc = pd.Series.nunique)
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     print(df)

# %%
#Computing Euclidean distances for beta-differences
for i in range(len(total)):
  total.loc[i, 'Distance'] = math.dist([0, 0, 0], [total.loc[i, 'Beta HML Diff'], total.loc[i, 'Beta Mkt-RF Diff'], total.loc[i, 'Beta SMB Diff']])
total
# Out:
#     Beta Mkt-RF_x Beta SMB_x Beta HML_x  Hier_x  K-means_x  HDBSCAN_x  \
# 0        1.104099  -0.008052  -0.232202       0          0          1
# 1        1.467816    0.59704   0.379124       1          1         -1
# 2        0.786409   0.386944   0.296801       1          1          1
# 3        1.293202  -0.126728  -0.430565       0          0         -1
# 4        1.015654   -0.24661  -0.118949       0          0          1
# ..            ...        ...        ...     ...        ...        ...
# 485      0.592636  -0.562231  -0.228679       0          0          1
# 486      0.855192  -0.012141  -0.248675       0          0          1
# 487      1.306125   1.041292  -0.432578       1          1         -1
# 488      1.171605   0.531263    1.36043       1          1         -1
# 489      0.909259   -0.24298  -0.486723       0          0          1
#
#                     Security             GICS Sector  \
# 0       Agilent Technologies             Health Care
# 1    American Airlines Group             Industrials
# 2         Advance Auto Parts  Consumer Discretionary
# 3                 Apple Inc.  Information Technology
# 4                     AbbVie             Health Care
# ..                       ...                     ...
# 485              Yum! Brands  Consumer Discretionary
# 486            Zimmer Biomet             Health Care
# 487       Zebra Technologies  Information Technology
# 488     Zions Bancorporation              Financials
# 489                   Zoetis             Health Care
#
#                               GICS Sub-Industry Ticker  ... Hier_y K-means_y  \
# 0                         Health Care Equipment      A  ...      0         1
# 1                            Passenger Airlines    AAL  ...      1         0
# 2                             Automotive Retail    AAP  ...      1         1
# 3    Technology Hardware, Storage & Peripherals   AAPL  ...      0         1
# 4                               Pharmaceuticals   ABBV  ...      0         1
# ..                                          ...    ...  ...    ...       ...
# 485                                 Restaurants    YUM  ...      0         1
# 486                       Health Care Equipment    ZBH  ...      1         1
# 487          Electronic Equipment & Instruments   ZBRA  ...      0         0
# 488                              Regional Banks   ZION  ...      1         0
# 489                             Pharmaceuticals    ZTS  ...      0         1
#
#     HDBSCAN_y  Beta Mkt-RF Diff  Beta SMB Diff  Beta HML Diff K-means_z  \
# 0           0         -0.170108       -0.04598       0.002813         1
# 1          -1          0.123292       0.601208       0.766289         0
# 2           0          0.066885      -0.321391      -0.023421         1
# 3           1          -0.06291      -0.292132       0.065309         1
# 4           0         -0.548519      -0.114855       0.184195         1
# ..        ...               ...            ...            ...       ...
# 485         0          0.131906       0.445211       0.384344         0
# 486         0          0.085577       0.180309       0.568373         0
# 487         0          0.029653      -0.918056       0.350024         1
# 488         0          0.210048       0.074596      -0.004383         1
# 489         0         -0.042758      -0.136294       0.224727         1
#
#     Hier_z HDBSCAN_z  Distance
# 0        1         1  0.176236
# 1        0        -1  0.981759
# 2        1         1  0.329111
# 3        1        -1  0.305882
# 4        1         1  0.589909
# ..     ...       ...       ...
# 485      0         1  0.602771
# 486      0         1  0.602398
# 487      1        -1  0.982966
# 488      0        -1  0.222944
# 489      1         1  0.266283
#
# [490 rows x 23 columns]

# %%
df = total
df.sort_values('Distance', ascending = False)
# Out:
#     Beta Mkt-RF_x Beta SMB_x Beta HML_x  Hier_x  K-means_x  HDBSCAN_x  \
# 314      1.097917   0.295933    0.13936       1          1          1
# 82        0.99228   0.251636   0.305787       1          1          1
# 377      1.198133   0.206112   0.076035       1          1          1
# 460      0.158007  -0.237999  -0.405874       0          0          1
# 443      1.015242   0.319607   0.304217       1          1          1
# ..            ...        ...        ...     ...        ...        ...
# 107      0.297843  -0.356801   0.098478       0          0          1
# 96       0.905912  -0.124397   0.229873       0          0          1
# 50       1.037423   0.800753  -0.525402       0          1         -1
# 438      1.011862  -0.034831   0.269761       0          1          1
# 421      0.991012   0.386161  -0.534619       0          1          1
#
#                            Security             GICS Sector  \
# 314  Norwegian Cruise Line Holdings  Consumer Discretionary
# 82                         Carnival  Consumer Discretionary
# 377           Royal Caribbean Group  Consumer Discretionary
# 460                          Ventas             Real Estate
# 443        United Airlines Holdings             Industrials
# ..                              ...                     ...
# 107           Campbell Soup Company        Consumer Staples
# 96                          Comcast  Communication Services
# 50                  Axon Enterprise             Industrials
# 438              Trane Technologies             Industrials
# 421                      Bio-Techne             Health Care
#
#                   GICS Sub-Industry Ticker  ... Hier_y K-means_y HDBSCAN_y  \
# 314  Hotels, Resorts & Cruise Lines   NCLH  ...      1         0        -1
# 82   Hotels, Resorts & Cruise Lines    CCL  ...      1         0        -1
# 377  Hotels, Resorts & Cruise Lines    RCL  ...      1         0        -1
# 460               Health Care REITs    VTR  ...      1         0         0
# 443              Passenger Airlines    UAL  ...      1         0        -1
# ..                              ...    ...  ...    ...       ...       ...
# 107          Packaged Foods & Meats    CPB  ...      0         1         0
# 96                Cable & Satellite  CMCSA  ...      0         1         0
# 50              Aerospace & Defense   AXON  ...      1         0        -1
# 438               Building Products     TT  ...      1         1         0
# 421  Life Sciences Tools & Services   TECH  ...      0         1        -1
#
#      Beta Mkt-RF Diff  Beta SMB Diff  Beta HML Diff K-means_z Hier_z  \
# 314          0.903684       1.282551       1.025904         0      0
# 82           0.989624       1.202297       0.892343         0      0
# 377          0.624146       0.990184       1.021813         0      0
# 460          0.855328       0.512683       1.160084         0      0
# 443          0.690441        0.76761       1.001853         0      0
# ..                ...            ...            ...       ...    ...
# 107         -0.029581       0.065822      -0.005197         1      1
# 96          -0.047213      -0.048665      -0.017989         1      1
# 50          -0.037633       0.027208      -0.048385         1      1
# 438         -0.018235       0.039991       0.018215         1      1
# 421         -0.041509      -0.000781        0.01972         1      1
#
#     HDBSCAN_z  Distance
# 314         1  1.874583
# 82          1  1.794756
# 377         1  1.553745
# 460         1  1.529780
# 443         1  1.438626
# ..        ...       ...
# 107         1  0.072350
# 96          1  0.070150
# 50         -1  0.067064
# 438         1  0.047577
# 421         1  0.045962
#
# [490 rows x 23 columns]
